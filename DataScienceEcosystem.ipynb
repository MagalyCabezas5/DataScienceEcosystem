# %%
# Proyecto Final - Ciencia de Datos

# %%
## Introducción

Este cuaderno contiene una serie de ejercicios para demostrar conocimientos básicos de ciencia de datos utilizando celdas Markdown y celdas de código.
A continuación, se presentan conceptos clave, bibliotecas, herramientas y ejemplos en Python.

# %%
# Lista de objetivos de este cuaderno
objetivos = [
    "Aprender conceptos clave de ciencia de datos",
    "Practicar Markdown y Python",
    "Aplicar expresiones y lógica básicas",
    "Presentar el trabajo de forma estructurada"
]
for objetivo in objetivos:
    print("- " + objetivo)
# Out:
# - Aprender conceptos clave de ciencia de datos
# - Practicar Markdown y Python
# - Aplicar expresiones y lógica básicas
# - Presentar el trabajo de forma estructurada

# %%
## Lenguajes de Programación en Ciencia de Datos

- Python
- R
- SQL
- Julia
- Scala

# %%
## Bibliotecas de Ciencia de Datos

- Pandas
- NumPy
- Matplotlib
- Seaborn
- Scikit-learn
- TensorFlow

# %%
## Herramientas de Ciencia de Datos

| Herramienta         | Categoría                 |
|---------------------|---------------------------|
| Jupyter Notebook    | IDE / Cuaderno interactivo |
| RStudio             | IDE                       |
| GitHub              | Control de versiones      |
| Watson Studio       | Plataforma en la nube     |
| VS Code             | Editor de código          |

# %%
## Ejemplos de Expresiones Aritméticas

A continuación se muestran ejemplos como:

- Suma: 5 + 3
- Resta: 10 - 4
- Multiplicación: 6 * 7
- División: 20 / 4

# %%
# Multiplicación y suma
a = 5
b = 3
resultado = a * b + 2
print("Resultado:", resultado)
# Out:
# Resultado: 17

# %%
# Convertir minutos a horas
minutos = 150
horas = minutos / 60
print(minutos, "minutos equivalen a", horas, "horas")
# Out:
# 150 minutos equivalen a 2.5 horas

# %%
# Lista de objetivos de este cuaderno
objetivos = [
    "Aprender conceptos clave de ciencia de datos",
    "Practicar Markdown y Python",
    "Aplicar expresiones y lógica básicas",
    "Presentar el trabajo de forma estructurada"
]
for objetivo in objetivos:
    print("- " + objetivo)

# %%
**Autor:**
Magaly Cabezas Guzmán
